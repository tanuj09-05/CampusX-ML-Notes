# %%
import pandas as pd
import seaborn as sns
"""
pandas data ko read, handle aur analyze karne ke liye use hoti hai.
sns seaborn ka alias hai. Seaborn data visualization library hai. Isse graphs/plots easily ban jaate hain.
"""
# Out:
# '\npandas data ko read, handle aur analyze karne ke liye use hoti hai.\nsns seaborn ka alias hai. Seaborn data visualization library hai. Isse graphs/plots easily ban jaate hain.\n'

# %%
df = pd.read_csv('train.csv')
"""
Yahan train.csv file read ho rahi hai.
pd.read_csv() CSV file ko DataFrame me convert karta hai.
df ke andar Titanic dataset store ho gaya.
"""
# Out:
# '\nYahan train.csv file read ho rahi hai.\npd.read_csv() CSV file ko DataFrame me convert karta hai.\ndf ke andar Titanic dataset store ho gaya.\n'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot
#
# """
# Countplot categorical column ki frequency count dikhata hai.
# Matlab har category me kitne records hain
# """

# %%
sns.countplot(df['Embarked'])
"""
Ye Embarked column ka countplot banata hai.
Embarked batata hai passenger kis port se chadha:
S: Southampton
C: Cherbourg
Q: Queenstown
"""
#df['Survived'].value_counts().plot(kind='bar')

"""
Ye Survived column ke counts ka bar chart banata.

value_counts() count karta hai ki 0 kitni baar hai aur 1 kitni baar hai.
plot(kind='bar') us count ko bar chart me show karta hai.
"""
# Out:
# "\nYe Survived column ke counts ka bar chart banata.\n\nvalue_counts() count karta hai ki 0 kitni baar hai aur 1 kitni baar hai.\nplot(kind='bar') us count ko bar chart me show karta hai.\n"

# %% [markdown]
# ## b. PieChart
#
# """
# Pie chart proportions/percentages dikhane ke liye use hota hai.
# """

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
"""
Is line ko parts me samjho: df['Sex']
Dataset ka Sex column select karta hai.

.value_counts()
Male aur female ka count nikalta hai.

Example conceptually:
male      577
female    314

.plot(kind='pie')
Is count ko pie chart me convert karta hai.

autopct='%.2f'
Pie chart me percentage show karta hai, 2 decimal places tak.
Example: 64.76, 35.24 type percentages.
Yani ye graph batata hai ki dataset me male aur female passengers ka proportion kya hai.
"""
# Out:
# "\nIs line ko parts me samjho: df['Sex']\nDataset ka Sex column select karta hai.\n\n.value_counts()\nMale aur female ka count nikalta hai.\n\nExample conceptually:\nmale      577\nfemale    314\n\n.plot(kind='pie')\nIs count ko pie chart me convert karta hai.\n\nautopct='%.2f'\nPie chart me percentage show karta hai, 2 decimal places tak.\nExample: 64.76, 35.24 type percentages.\nYani ye graph batata hai ki dataset me male aur female passengers ka proportion kya hai.\n"

# %% [markdown]
# <div style="border-top:black 2px solid"></div>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
"""
plt.hist(df['Age'],bins=5)
Ye Age column ka histogram banata hai.
bins=5 ka matlab age values ko 5 intervals/ranges me divide karo.

Output:
array([100., 346., 188., 69., 11.])

Iska matlab 5 bins me approx itne passengers aaye.

Notebook ke output ke hisaab se bins ye the:
0.42 to 16.336
16.336 to 32.252
32.252 to 48.168
48.168 to 64.084
64.084 to 80

Interpretation:
Sabse zyada passengers 16 se 32 age range ke aas-paas hain.
Bahut kam passengers 64 se 80 age range me hain.
"""
# Out:
# "\nplt.hist(df['Age'],bins=5)\nYe Age column ka histogram banata hai.\nbins=5 ka matlab age values ko 5 intervals/ranges me divide karo.\n\nOutput:\narray([100., 346., 188., 69., 11.])\n\nIska matlab 5 bins me approx itne passengers aaye.\n\nNotebook ke output ke hisaab se bins ye the:\n0.42 to 16.336\n16.336 to 32.252\n32.252 to 48.168\n48.168 to 64.084\n64.084 to 80\n\nInterpretation:\nSabse zyada passengers 16 se 32 age range ke aas-paas hain.\nBahut kam passengers 64 se 80 age range me hain.\n"

# %% [markdown]
# ## b. Distplot

# %%
sns.distplot(df['Age'])
"""
Ye Age column ka distribution plot banata hai.

Isse hume pata chalta hai:
Age data normally distributed hai ya skewed?
Most passengers kis age group me hain?
Extreme values hain ya nahi?

Important note: distplot ab seaborn me deprecated hai. Naye version me ye use karna better hai:
sns.histplot(df['Age'], kde=True)
kde=True smooth density curve add karta hai.
"""
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_26124\1691643440.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# "\nYe Age column ka distribution plot banata hai.\n\nIsse hume pata chalta hai:\nAge data normally distributed hai ya skewed?\nMost passengers kis age group me hain?\nExtreme values hain ya nahi?\n\nImportant note: distplot ab seaborn me deprecated hai. Naye version me ye use karna better hai:\nsns.histplot(df['Age'], kde=True)\nkde=True smooth density curve add karta hai.\n"

# %% [markdown]
# ## c. Boxplot
#
# """
# Boxplot numerical data ke spread, median aur outliers ko samajhne ke liye use hota hai.
#
# Boxplot se hume ye cheezein milti hain:
#
# Median
#
# 25th percentile
#
# 75th percentile
#
# Minimum/maximum range
#
# Outliers
# """

# %%
sns.boxplot(df['Age'])
"""
Ye Age column ka boxplot banata hai.
Boxplot se hume age ka spread dikhta hai.
Agar kuch points box ke bahar dikhte hain, to wo possible outliers hote hain.
"""
# Out:
# '\nYe Age column ka boxplot banata hai.\nBoxplot se hume age ka spread dikhta hai.\nAgar kuch points box ke bahar dikhte hain, to wo possible outliers hote hain.\n'

# %%
df['Age'].min()
"""
Ye Age column ki minimum value nikalta hai.

Output: 0.42
Matlab dataset me sabse chhoti age 0.42 years hai.
"""
# Out:
# '\nYe Age column ki minimum value nikalta hai.\n\nOutput: 0.42\nMatlab dataset me sabse chhoti age 0.42 years hai.\n'

# %%
df['Age'].max()
"""
Ye Age column ki maximum value nikalta hai.

Output:80.0
Matlab sabse elderly passenger ki age 80 years hai.
"""
# Out:
# '\nYe Age column ki maximum value nikalta hai.\n\nOutput:80.0\nMatlab sabse elderly passenger ki age 80 years hai.\n'

# %%
df['Age'].mean()
"""
Ye Age column ka average nikalta hai.

Output: 29.69911764705882
Matlab average age approx 29.7 years hai.
"""
# Out:
# '\nYe Age column ka average nikalta hai.\n\nOutput: 29.69911764705882\nMatlab average age approx 29.7 years hai.\n'

# %%
df['Age'].skew()
"""
Ye Age column ka skewness calculate karta hai.

Skewness data ke distribution ka tilt batata hai.
Output: 0.38910778230082704

Positive skewness ka matlab data right side ki taraf thoda stretched hai.
Yahan value 0.389 hai, jo mild positive skewness hai.
Matlab mostly passengers younger/middle age group me hain, lekin kuch older passengers ki wajah se distribution right side thoda tail bana raha hai.
"""
# Out:
# '\nYe Age column ka skewness calculate karta hai.\n\nSkewness data ke distribution ka tilt batata hai.\nOutput: 0.38910778230082704\n\nPositive skewness ka matlab data right side ki taraf thoda stretched hai.\nYahan value 0.389 hai, jo mild positive skewness hai.\nMatlab mostly passengers younger/middle age group me hain, lekin kuch older passengers ki wajah se distribution right side thoda tail bana raha hai.\n'
