# %% [markdown]
# Preprocessing

# %%
import numpy as np
import pandas as pd

"https://chatgpt.com/s/t_6a788116463c819195ea7cb16b65e366"

"https://youtu.be/dr7z7a_8lQw?list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH"
# Out:
# 'https://youtu.be/dr7z7a_8lQw?list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH'

# %%
df = pd.read_csv('\Tanuj CampusX AIML Notes\CampusX-ML-Notes\lec13 End to end toy project\\placement.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8540\1157740390.py:1: SyntaxWarning: invalid escape sequence '\T'
#   df = pd.read_csv('\Tanuj CampusX AIML Notes\CampusX-ML-Notes\lec13 End to end toy project\\placement.csv')

# %%
df.head()

# df.head() Pandas ka function hai jo DataFrame ki shuru ki rows dikhata hai.
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]
"""
df.iloc → integer position (index number) से rows/columns select करता है।
: (पहला) → सभी rows लो।
1: (दूसरा) → column index 1 से आख़िर तक सभी columns लो।
"""
# Out:
# '\ndf.iloc → integer position (index number) से rows/columns select करता है।\n: (पहला) → सभी rows लो।\n1: (दूसरा) → column index 1 से आख़िर तक सभी columns लो।\n'

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %% [markdown]
# # EDA

# %% [markdown]
# https://chatgpt.com/s/t_6a63b6fc6540819196da5624c96b8ee5

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %% [markdown]
# ## 1. Extract input and output cols

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 63   6.3  128.0
# 67   5.0  118.0
# 22   4.9  120.0
# 50   3.5  233.0
# 3    7.4  132.0
# ..   ...    ...
# 28   5.2   90.0
# 20   6.6  120.0
# 26   7.0  199.0
# 68   4.0   75.0
# 60   6.9  139.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 63    1
# 67    0
# 22    0
# 50    0
# 3     1
#      ..
# 28    0
# 20    1
# 26    1
# 68    0
# 60    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 94   4.7   52.0
# 97   6.7  182.0
# 58   8.0   79.0
# 14   6.1  103.0
# 57   6.5  130.0
# 45   6.0   66.0
# 91   7.5  158.0
# 6    5.7  143.0
# 46   5.3  114.0
# 69   8.5  120.0

# %% [markdown]
# ## 2. Scale the values

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.3254    ,  0.0864661 ],
#        [-0.83179757, -0.16537691],
#        [-0.92081277, -0.11500831],
#        [-2.16702554,  2.73081772],
#        [ 1.30456718,  0.18720331],
#        [ 0.94850639,  1.27012825],
#        [ 0.14736961,  0.79162653],
#        [-0.20869119,  1.11902245],
#        [-0.92081277,  0.23757191],
#        [-0.47573678, -0.26611412],
#        [-0.47573678,  0.36349341],
#        [ 2.10570396,  1.09383815],
#        [-0.92081277,  0.66570503],
#        [-1.00982797,  0.96791664],
#        [ 0.5924456 ,  0.33830911],
#        [-1.00982797, -0.31648272],
#        [ 1.66062797, -0.26611412],
#        [ 0.05835441,  0.61533642],
#        [ 1.48259758, -0.89572164],
#        [ 0.14736961, -1.50014487],
#        [-0.11967599,  1.04346954],
#        [ 0.05835441, -0.56832573],
#        [ 0.05835441, -0.0142711 ],
#        [ 0.3254    ,  0.0612818 ],
#        [ 0.4144152 , -0.21574551],
#        [-0.83179757, -1.55051347],
#        [-0.47573678,  0.26275621],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.09884317, -1.82754079],
#        [ 0.68146079,  1.44641836],
#        [ 1.83865837, -1.14756466],
#        [ 0.14736961, -0.54314143],
#        [ 0.5034304 ,  0.1368347 ],
#        [ 0.05835441, -1.47496057],
#        [ 1.39358238,  0.84199514],
#        [-0.20869119,  0.46423062],
#        [-0.56475198, -0.26611412],
#        [ 2.28373436, -0.11500831]])

# %% [markdown]
# ## Train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluate the model/model selection

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 94    0
# 97    1
# 58    1
# 14    0
# 57    1
# 45    1
# 91    1
# 6     0
# 46    0
# 69    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %% [markdown]
# https://youtu.be/dr7z7a_8lQw?list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH
