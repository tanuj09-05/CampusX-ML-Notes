# %%
import pandas as pd
import requests

"""
https://youtu.be/roTZJaxjnJc?list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH
"""

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

"""
Ye line TMDB API se data fetch kar rahi hai.
response =
API ka response response variable me store hoga.

requests.get(...)
Ye API URL par GET request bhejta hai.
GET request ka matlab: server se data maangna.

URL breakdown:
https://api.themoviedb.org/3/movie/top_rated
Ye endpoint top rated movies ka data deta hai.

api_key=...
API key hai. API ko access karne ke liye key chahiye hoti hai.

language=en-US
Movies ka data English/US language me chahiye.

page=1
Page number 1 ka data chahiye.

API ek baar me limited movies deti hai, isliye pages use hote hain.
"""
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id                        title  \
# 0   19404  Dilwale Dulhania Le Jayenge
# 1  724089    Gabriel's Inferno Part II
# 2     278     The Shawshank Redemption
# 3     238                The Godfather
# 4  761053   Gabriel's Inferno Part III
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.433
# 1  Professor Gabriel Emerson finally learns the t...   2020-07-31       8.439
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      65.570
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      63.277
# 4  The final part of the film adaption of the ero...   2020-11-19      26.691
#
#    vote_average  vote_count
# 0           8.7        2763
# 1           8.7        1223
# 2           8.7       18637
# 3           8.7       14052
# 4           8.7         773

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

    """
Ye main part hai.
Yahaan multiple API pages se movies ka data fetch kiya ja raha hai.

for i in range(1,429):
Loop page numbers ke liye chal raha hai.
range(1,429) ka matlab:
Start: 1
End: 429 se pehle tak
Actual values:
1, 2, 3, ..., 428
Matlab total 428 pages fetch honge.

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
Har loop me API request bheji ja rahi hai.

Important part:
page={}.format(i)
Yahaan page number dynamic ban raha hai.
Agar i = 1, URL me:
page=1
Agar i = 2, URL me:
page=2
Agar i = 428, URL me:
page=428
Matlab har baar different page ka data fetch hoga.

temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
Har page ke response ko DataFrame me convert kiya ja raha hai.
Sirf selected columns rakhe ja rahe hain.
temp_df me ek page ka data hoga.
Usually TMDB ek page me 20 movies deta hai.

df = df.append(temp_df,ignore_index=True)
Yahaan temp_df ko final df ke andar add kiya ja raha hai.

df.append(temp_df)
Purane df ke neeche temp_df ki rows add karta hai.

ignore_index=True
Index ko reset karta hai.
Agar ye na lagao, to har page ka index 0 se start ho sakta hai.

ignore_index=True se final index continuous hota hai:
0, 1, 2, 3, ...

Important note:
New pandas versions me .append() deprecated/removed ho chuka hai.
Modern code me better hai:
pd.concat()
"""

# %%
df
# Out:
#           id                        title  \
# 0      19404  Dilwale Dulhania Le Jayenge
# 1     724089    Gabriel's Inferno Part II
# 2        278     The Shawshank Redemption
# 3        238                The Godfather
# 4     761053   Gabriel's Inferno Part III
# ...      ...                          ...
# 8546   13805               Disaster Movie
# 8547    5491            Battlefield Earth
# 8548   14164         Dragonball Evolution
# 8549   11059            House of the Dead
# 8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4     The final part of the film adaption of the ero...   2020-11-19
# ...

# %%
df.shape
"""
Ye DataFrame ka size batata hai.

Output format hota hai:
(rows, columns)
Example:
(8560, 7)

Matlab:
8560 rows
7 columns

Agar har page me 20 movies hain aur 428 pages hain:
428 * 20 = 8560
To expected rows around 8560 ho sakti hain.
"""
# Out:
# (8551, 7)

# %%
df.to_csv('movies.csv')
"""
Final data ko CSV file me save karo.
"""
